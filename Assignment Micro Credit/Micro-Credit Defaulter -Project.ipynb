# %% [markdown]
# # 1 Problem Statement
# A Microfinance Institution (MFI) is an organization that offers financial services to low income populations. MFS becomes very useful when targeting especially the unbanked poor families living in remote areas with not much sources of income. The Microfinance services (MFS) provided by MFI are Group Loans, Agricultural Loans, Individual Business Loans and so on.
# Many microfinance institutions (MFI), experts and donors are supporting the idea of using mobile financial services (MFS) which they feel are more convenient and efficient, and cost saving, than the traditional high-touch model used since long for the purpose of delivering microfinance services. Though, the MFI industry is primarily focusing on low income families and are very useful in such areas, the implementation of MFS has been uneven with both significant challenges and successes.
# Today, microfinance is widely accepted as a poverty-reduction tool, representing $70 billion in outstanding loans and a global outreach of 200 million clients.
# We are working with one such client that is in Telecom Industry. They are a fixed wireless telecommunications network provider. They have launched various products and have developed its business and organization based on the budget operator model, offering better products at Lower Prices to all value conscious customers through a strategy of disruptive innovation that focuses on the subscriber.
# They understand the importance of communication and how it affects a person’s life, thus, focusing on providing their services and products to low income families and poor customers that can help them in the need of hour.
# They are collaborating with an MFI to provide micro-credit on mobile balances to be paid back in 5 days. The Consumer is believed to be defaulter if he deviates from the path of paying back the loaned amount within the time duration of 5 days. For the loan amount of 5 (in Indonesian Rupiah), payback amount should be 6 (in Indonesian Rupiah), while, for the loan amount of 10 (in Indonesian Rupiah), the payback amount should be 12 (in Indonesian Rupiah).
# The sample data is provided to us from our client database. It is hereby given to you for this exercise. In order to improve the selection of customers for the credit, the client wants some predictions that could help them in further investment and improvement in selection of customers.
# Exercise:
# Build a model which can be used to predict in terms of a probability for each loan transaction, whether the customer will be paying back the loaned amount within 5 days of insurance of loan. In this case, Label ‘1’ indicates that the loan has been payed i.e. Non- defaulter, while, Label ‘0’ indicates that the loan has not been payed i.e. defaulter.
# Points to Remember:
# •	There are no null values in the dataset.
# •	There may be some customers with no loan history.
# •	The dataset is imbalanced. Label ‘1’ has approximately 87.5% records, while, label ‘0’ has approximately 12.5% records.
# •	For some features, there may be values which might not be realistic. You may have to observe them and treat them with a suitable explanation.
# •	You might come across outliers in some features which you need to handle as per your understanding. Keep in mind that data is expensive and we cannot lose more than 7-8% of the data.
# Find Enclosed the Data Description File and The Sample Data for the Modeling Exercise.

# %% [markdown]
# # 2. Columns Description

# %% [markdown]
# - label:Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}
# - msisdn:mobile number of user
# - aon:	age on cellular network in days
# - daily_decr30:	Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)
# - daily_decr90:	Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)
# - rental30:	Average main account balance over last 30 days
# - rental90:	Average main account balance over last 90 days
# - last_rech_date_ma:	Number of days till last recharge of main account
# - last_rech_date_da:	Number of days till last recharge of data account
# - last_rech_amt_ma:	Amount of last recharge of main account (in Indonesian Rupiah)
# - cnt_ma_rech30:	Number of times main account got recharged in last 30 days
# - fr_ma_rech30:	Frequency of main account recharged in last 30 days
# - sumamnt_ma_rech30:	Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)
# - medianamnt_ma_rech30:	Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah)
# - medianmarechprebal30:	Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)
# - cnt_ma_rech90:	Number of times main account got recharged in last 90 days
# - fr_ma_rech90:	Frequency of main account recharged in last 90 days
# - sumamnt_ma_rech90:	Total amount of recharge in main account over last 90 days (in Indonasian Rupiah)
# - medianamnt_ma_rech90:	Median of amount of recharges done in main account over last 90 days at user level (in Indonasian Rupiah)
# - medianmarechprebal90:	Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)
# - cnt_da_rech30:	Number of times data account got recharged in last 30 days
# - fr_da_rech30:	Frequency of data account recharged in last 30 days
# - cnt_da_rech90:	Number of times data account got recharged in last 90 days
# - fr_da_rech90:	Frequency of data account recharged in last 90 days
# - cnt_loans30:	Number of loans taken by user in last 30 days
# - amnt_loans30:	Total amount of loans taken by user in last 30 days
# - maxamnt_loans30:	maximum amount of loan taken by the user in last 30 days
# - medianamnt_loans30:	Median of amounts of loan taken by the user in last 30 days
# - cnt_loans90:	Number of loans taken by user in last 90 days
# - amnt_loans90:	Total amount of loans taken by user in last 90 days
# - maxamnt_loans90:	maximum amount of loan taken by the user in last 90 days
# - medianamnt_loans90:	Median of amounts of loan taken by the user in last 90 days
# - payback30:	Average payback time in days over last 30 days
# - payback90:	Average payback time in days over last 90 days
# - pcircle:	telecom circle
# - pdate:	date

# %% [markdown]
# # 3 Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 4.Data Collection

# %%
data=pd.read_csv("Data_file.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %% [markdown]
# # 5.Basic Data Exploration

# %% [markdown]
# ## 5.1 Shape of Dataset

# %%
data.shape
# Out:
# (209593, 37)

# %% [markdown]
# **Observation**
# - As we can see there are 209593 observation/sample/row available in dataset.
# - There are 37 columns are avaialble in dataset

# %% [markdown]
# ## 5.2 Dataset Columns data type

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %% [markdown]
# **Observation**
# - There are 21 columns which data type is float, 13 columns are int type and 3 columns are object type.

# %% [markdown]
# ## 5.3 Statistic Summary

# %%
data.describe().transpose()
# Out:
#                          count           mean           std           min  \
# Unnamed: 0            209593.0  104797.000000  60504.431823      1.000000
# label                 209593.0       0.875177      0.330519      0.000000
# aon                   209593.0    8112.343445  75696.082531    -48.000000
# daily_decr30          209593.0    5381.402289   9220.623400    -93.012667
# daily_decr90          209593.0    6082.515068  10918.812767    -93.012667
# rental30              209593.0    2692.581910   4308.586781 -23737.140000
# rental90              209593.0    3483.406534   5770.461279 -24720.580000
# last_rech_date_ma     209593.0    3755.847800  53905.892230    -29.000000
# last_rech_date_da     209593.0    3712.202921  53374.833430    -29.000000
# last_rech_amt_ma      209593.0    2064.452797   2370.786034      0.000000
# cnt_ma_rech30         209593.0       3.978057      4.256090      0.000000
# fr_ma_rech30          209593.0    3737.355121  53643.625172      0.000000
# ...

# %% [markdown]
# **Observation**
# - No null value in dataset.
# - Unnamed:0 column need to drop as this columns would not require for our analysis.
# - We can analyse that data distribution for columns are not normal as there are difference in value of mean and 50% data value.
# - There are some columns where we have zero value.

# %%
data.drop("Unnamed: 0",axis=1,inplace=True)

# %% [markdown]
# ## 5.4 Checking unique value in data columns

# %%
data.nunique()
# Out:
# label                        2
# msisdn                  186243
# aon                       4507
# daily_decr30            147025
# daily_decr90            158669
# rental30                132148
# rental90                141033
# last_rech_date_ma         1186
# last_rech_date_da         1174
# last_rech_amt_ma            70
# cnt_ma_rech30               71
# fr_ma_rech30              1083
# sumamnt_ma_rech30        15141
# medianamnt_ma_rech30       510
# medianmarechprebal30     30428
# cnt_ma_rech90              110
# fr_ma_rech90                89
# sumamnt_ma_rech90        31771
# medianamnt_ma_rech90       608
# medianmarechprebal90     29785
# cnt_da_rech30             1066
# fr_da_rech30              1072
# cnt_da_rech90               27
# fr_da_rech90                46
# cnt_loans30                 40
# amnt_loans30                48
# maxamnt_loans30           1050
# medianamnt_loans30           6
# cnt_loans90               1110
# amnt_loans90                69
# ...

# %% [markdown]
# ## 5.5 Seperating Numerical and Categorical value

# %%
numeric_feat=[]
categorical_feat=[]
num=["int64","float64"]
cat=["O"]
for column in data.columns:
    if data[column].dtypes in num:
        numeric_feat.append(column)
    if data[column].dtypes in cat:
        categorical_feat.append(column)

# %%
data.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# ## 5.6 Dealing with negative value

# %%
data["aon"] = np.where(data["aon"] < 0, 0, data["aon"])

# %%
data["daily_decr30"] = np.where(data["daily_decr30"] < 0, 0, data["daily_decr30"])

# %%
data["daily_decr90"] = np.where(data["daily_decr90"] < 0, 0, data["daily_decr90"])

# %%
data["rental30"] = np.where(data["rental30"] < 0, 0, data["rental30"])

# %%
data["rental90"] = np.where(data["rental90"] < 0, 0, data["rental90"])

# %%
data["last_rech_date_ma"] = np.where(data["last_rech_date_ma"] < 0, 0, data["last_rech_date_ma"])

# %%
data["last_rech_date_da"] = np.where(data["last_rech_date_da"] < 0, 0, data["last_rech_date_da"])

# %%
data["medianmarechprebal30"] = np.where(data["medianmarechprebal30"] < 0, 0, data["medianmarechprebal30"])

# %%
data["medianmarechprebal90"] = np.where(data["medianmarechprebal90"] < 0, 0, data["medianmarechprebal90"])

# %% [markdown]
# # 6. Exploratory Data Analysis

# %% [markdown]
# ### Average Daily Amount Spent

# %%
sns.scatterplot(x="daily_decr30",y="daily_decr90",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='daily_decr30', ylabel='daily_decr90'>

# %% [markdown]
# ### Average Main Account Balance

# %%
sns.scatterplot(x="rental30",y="rental90",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='rental30', ylabel='rental90'>

# %% [markdown]
# ### No. of days last recharge

# %%
sns.scatterplot(x="last_rech_date_ma",y="last_rech_date_da",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='last_rech_date_ma', ylabel='last_rech_date_da'>

# %% [markdown]
# ### Amount of Last recharge main account

# %%
sns.scatterplot(x="last_rech_amt_ma",y="label",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='last_rech_amt_ma', ylabel='label'>

# %% [markdown]
# ### Number of time main account recharged

# %%
sns.scatterplot(x="cnt_ma_rech30",y="label",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='label'>

# %% [markdown]
# ### Frequency of main account recharged

# %%
sns.scatterplot(x="fr_ma_rech30",y="label",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='fr_ma_rech30', ylabel='label'>

# %% [markdown]
# ### Total Amount recharge main account

# %%
sns.scatterplot(x="sumamnt_ma_rech90",y="label",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech90', ylabel='label'>

# %% [markdown]
# ### Median of amount of recharges done in main account

# %%
sns.scatterplot(x="medianamnt_ma_rech30",y="medianamnt_ma_rech90",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech30', ylabel='medianamnt_ma_rech90'>

# %% [markdown]
# ### Median of main account balance just before recharge

# %%
sns.scatterplot(x="medianmarechprebal30",y="medianmarechprebal90",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='medianmarechprebal30', ylabel='medianmarechprebal90'>

# %% [markdown]
# ### Number of times data account got recharged

# %%
sns.scatterplot(x="cnt_ma_rech30",y="cnt_ma_rech90",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='cnt_ma_rech90'>

# %% [markdown]
# ### Frequency of data account recharged

# %%
sns.scatterplot(x="fr_da_rech30",y="fr_da_rech90",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='fr_da_rech30', ylabel='fr_da_rech90'>

# %% [markdown]
# ### Number of loans taken by user

# %%
sns.scatterplot(x="cnt_loans30",y="cnt_loans90",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='cnt_loans30', ylabel='cnt_loans90'>

# %% [markdown]
# ### Total amount of loans taken by user

# %%
sns.scatterplot(x="amnt_loans30",y="amnt_loans90",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='amnt_loans30', ylabel='amnt_loans90'>

# %% [markdown]
# ### maximum amount of loan taken by the user

# %%
sns.scatterplot(x="maxamnt_loans30",y="maxamnt_loans90",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='maxamnt_loans30', ylabel='maxamnt_loans90'>

# %% [markdown]
# ### Median of amounts of loan taken by the user

# %%
sns.scatterplot(x="medianamnt_loans30",y="medianamnt_loans90",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='medianamnt_loans30', ylabel='medianamnt_loans90'>

# %% [markdown]
# ### Average payback time in days

# %%
sns.scatterplot(x="payback30",y="payback90",data=data,hue="label")
# Out:
# <AxesSubplot:xlabel='payback30', ylabel='payback90'>

# %%
plt.figure(figsize=(15,20),facecolor="white")
plotnumber=1
for column in numeric_feat:
    if plotnumber <=33:
        ax=plt.subplot(11,3,plotnumber)
        sns.distplot(data[column])
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# **Observation**
# - We can see that there are lot of data skeewness.

# %%
plt.figure(figsize=(15,20),facecolor="white")
plotnumber=1
for column in numeric_feat:
    if plotnumber <=33:
        ax=plt.subplot(11,3,plotnumber)
        sns.boxplot(data[column])
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# **Observation**
# - Data columns having outlier

# %%
data.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# # 7. Dealing with Outliers

# %%
plt.figure(figsize=(15,20),facecolor="white")
plotnumber=1
for column in numeric_feat:
    if plotnumber <=33:
        ax=plt.subplot(11,3,plotnumber)
        sns.boxplot(data[column])
    plotnumber+=1
plt.tight_layout()

# %%
sns.boxplot(data["aon"])
# Out:
# <AxesSubplot:xlabel='aon'>

# %%
upper_limit=data["aon"].mean()+3*data["aon"].std()
lower_limit=data["aon"].mean()-3*data["aon"].std()

data["aon"]=np.where(data["aon"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["aon"]<lower_limit,
                           lower_limit,
                           data["aon"]
                        )
                    )

# %%
sns.boxplot(data["aon"])
# Out:
# <AxesSubplot:xlabel='aon'>

# %%
sns.boxplot(data["daily_decr30"])
# Out:
# <AxesSubplot:xlabel='daily_decr30'>

# %%
upper_limit=data["daily_decr30"].mean()+3*data["daily_decr30"].std()
lower_limit=data["daily_decr30"].mean()-3*data["daily_decr30"].std()

data["daily_decr30"]=np.where(data["daily_decr30"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["daily_decr30"]<lower_limit,
                           lower_limit,
                           data["daily_decr30"]
                        )
                    )

# %%
sns.boxplot(data["daily_decr30"])
# Out:
# <AxesSubplot:xlabel='daily_decr30'>

# %%
sns.boxplot(data["daily_decr90"])
# Out:
# <AxesSubplot:xlabel='daily_decr90'>

# %%
upper_limit=data["daily_decr90"].mean()+3*data["daily_decr90"].std()
lower_limit=data["daily_decr90"].mean()-3*data["daily_decr90"].std()

data["daily_decr90"]=np.where(data["daily_decr90"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["daily_decr90"]<lower_limit,
                           lower_limit,
                           data["daily_decr90"]
                        )
                    )

# %%
sns.boxplot(data["daily_decr90"])
# Out:
# <AxesSubplot:xlabel='daily_decr90'>

# %%
sns.boxplot(data["rental30"])
# Out:
# <AxesSubplot:xlabel='rental30'>

# %%
upper_limit=data["rental30"].mean()+3*data["rental30"].std()
lower_limit=data["rental30"].mean()-3*data["rental30"].std()

data["rental30"]=np.where(data["rental30"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["rental30"]<lower_limit,
                           lower_limit,
                           data["rental30"]
                        )
                    )

# %%
sns.boxplot(data["rental30"])
# Out:
# <AxesSubplot:xlabel='rental30'>

# %%
sns.boxplot(data["rental90"])
# Out:
# <AxesSubplot:xlabel='rental90'>

# %%
upper_limit=data["rental90"].mean()+3*data["rental90"].std()
lower_limit=data["rental90"].mean()-3*data["rental90"].std()

data["rental90"]=np.where(data["rental90"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["rental90"]<lower_limit,
                           lower_limit,
                           data["rental90"]
                        )
                    )

# %%
sns.boxplot(data["rental90"])
# Out:
# <AxesSubplot:xlabel='rental90'>

# %%
sns.boxplot(data["last_rech_date_ma"])
# Out:
# <AxesSubplot:xlabel='last_rech_date_ma'>

# %%
upper_limit=data["last_rech_date_ma"].mean()+3*data["last_rech_date_ma"].std()
lower_limit=data["last_rech_date_ma"].mean()-3*data["last_rech_date_ma"].std()

data["last_rech_date_ma"]=np.where(data["last_rech_date_ma"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["last_rech_date_ma"]<lower_limit,
                           lower_limit,
                           data["last_rech_date_ma"]
                        )
                    )

# %%
sns.boxplot(data["last_rech_date_ma"])
# Out:
# <AxesSubplot:xlabel='last_rech_date_ma'>

# %%
sns.boxplot(data["last_rech_date_da"])
# Out:
# <AxesSubplot:xlabel='last_rech_date_da'>

# %%
upper_limit=data["last_rech_date_da"].mean()+3*data["last_rech_date_da"].std()
lower_limit=data["last_rech_date_da"].mean()-3*data["last_rech_date_da"].std()

data["last_rech_date_da"]=np.where(data["last_rech_date_da"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["last_rech_date_da"]<lower_limit,
                           lower_limit,
                           data["last_rech_date_da"]
                        )
                    )

# %%
sns.boxplot(data["last_rech_date_da"])
# Out:
# <AxesSubplot:xlabel='last_rech_date_da'>

# %%
sns.boxplot(data["cnt_ma_rech30"])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30'>

# %%
upper_limit=data["cnt_ma_rech30"].mean()+3*data["cnt_ma_rech30"].std()
lower_limit=data["cnt_ma_rech30"].mean()-3*data["cnt_ma_rech30"].std()

data["cnt_ma_rech30"]=np.where(data["cnt_ma_rech30"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["cnt_ma_rech30"]<lower_limit,
                           lower_limit,
                           data["cnt_ma_rech30"]
                        )
                    )

# %%
sns.boxplot(data["cnt_ma_rech30"])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30'>

# %%
sns.boxplot(data["cnt_ma_rech90"])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech90'>

# %%
upper_limit=data["cnt_ma_rech90"].mean()+3*data["cnt_ma_rech90"].std()
lower_limit=data["cnt_ma_rech90"].mean()-3*data["cnt_ma_rech90"].std()

data["cnt_ma_rech90"]=np.where(data["cnt_ma_rech90"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["cnt_ma_rech90"]<lower_limit,
                           lower_limit,
                           data["cnt_ma_rech90"]
                        )
                    )

# %%
sns.boxplot(data["cnt_ma_rech90"])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech90'>

# %%
sns.boxplot(data["sumamnt_ma_rech90"])
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech90'>

# %%
upper_limit=data["sumamnt_ma_rech90"].mean()+3*data["sumamnt_ma_rech90"].std()
lower_limit=data["sumamnt_ma_rech90"].mean()-3*data["sumamnt_ma_rech90"].std()

data["sumamnt_ma_rech90"]=np.where(data["sumamnt_ma_rech90"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["sumamnt_ma_rech90"]<lower_limit,
                           lower_limit,
                           data["sumamnt_ma_rech90"]
                        )
                    )

# %%
sns.boxplot(data["sumamnt_ma_rech90"])
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech90'>

# %%
sns.boxplot(data["medianamnt_ma_rech90"])
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech90'>

# %%
upper_limit=data["medianamnt_ma_rech90"].mean()+3*data["medianamnt_ma_rech90"].std()
lower_limit=data["medianamnt_ma_rech90"].mean()-3*data["medianamnt_ma_rech90"].std()

data["medianamnt_ma_rech90"]=np.where(data["medianamnt_ma_rech90"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["medianamnt_ma_rech90"]<lower_limit,
                           lower_limit,
                           data["medianamnt_ma_rech90"]
                        )
                    )

# %%
sns.boxplot(data["medianamnt_ma_rech90"])
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech90'>

# %%
sns.boxplot(data["medianmarechprebal90"])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal90'>

# %%
upper_limit=data["medianmarechprebal90"].mean()+3*data["medianmarechprebal90"].std()
lower_limit=data["medianmarechprebal90"].mean()-3*data["medianmarechprebal90"].std()

data["medianmarechprebal90"]=np.where(data["medianmarechprebal90"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["medianmarechprebal90"]<lower_limit,
                           lower_limit,
                           data["medianmarechprebal90"]
                        )
                    )

# %%
sns.boxplot(data["medianmarechprebal90"])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal90'>

# %%
sns.boxplot(data["cnt_da_rech30"])
# Out:
# <AxesSubplot:xlabel='cnt_da_rech30'>

# %%
upper_limit=data["cnt_da_rech30"].mean()+3*data["cnt_da_rech30"].std()
lower_limit=data["cnt_da_rech30"].mean()-3*data["cnt_da_rech30"].std()

data["cnt_da_rech30"]=np.where(data["cnt_da_rech30"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["cnt_da_rech30"]<lower_limit,
                           lower_limit,
                           data["cnt_da_rech30"]
                        )
                    )

# %%
sns.boxplot(data["cnt_da_rech30"])
# Out:
# <AxesSubplot:xlabel='cnt_da_rech30'>

# %%
sns.boxplot(data["fr_da_rech30"])
# Out:
# <AxesSubplot:xlabel='fr_da_rech30'>

# %%
upper_limit=data["fr_da_rech30"].mean()+3*data["fr_da_rech30"].std()
lower_limit=data["fr_da_rech30"].mean()-3*data["fr_da_rech30"].std()

data["fr_da_rech30"]=np.where(data["fr_da_rech30"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["fr_da_rech30"]<lower_limit,
                           lower_limit,
                           data["fr_da_rech30"]
                        )
                    )

# %%
sns.boxplot(data["fr_da_rech30"])
# Out:
# <AxesSubplot:xlabel='fr_da_rech30'>

# %%
sns.boxplot(data["cnt_da_rech90"])
# Out:
# <AxesSubplot:xlabel='cnt_da_rech90'>

# %%
upper_limit=data["cnt_da_rech90"].mean()+3*data["cnt_da_rech90"].std()
lower_limit=data["cnt_da_rech90"].mean()-3*data["cnt_da_rech90"].std()

data["cnt_da_rech90"]=np.where(data["cnt_da_rech90"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["cnt_da_rech90"]<lower_limit,
                           lower_limit,
                           data["cnt_da_rech90"]
                        )
                    )

# %%
sns.boxplot(data["cnt_da_rech90"])
# Out:
# <AxesSubplot:xlabel='cnt_da_rech90'>

# %%
sns.boxplot(data["fr_da_rech90"])
# Out:
# <AxesSubplot:xlabel='fr_da_rech90'>

# %%
upper_limit=data["fr_da_rech90"].mean()+3*data["fr_da_rech90"].std()
lower_limit=data["fr_da_rech90"].mean()-3*data["fr_da_rech90"].std()

data["fr_da_rech90"]=np.where(data["fr_da_rech90"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["fr_da_rech90"]<lower_limit,
                           lower_limit,
                           data["fr_da_rech90"]
                        )
                    )

# %%
sns.boxplot(data["fr_da_rech90"])
# Out:
# <AxesSubplot:xlabel='fr_da_rech90'>

# %%
sns.boxplot(data["cnt_loans30"])
# Out:
# <AxesSubplot:xlabel='cnt_loans30'>

# %%
upper_limit=data["cnt_loans30"].mean()+3*data["cnt_loans30"].std()
lower_limit=data["cnt_loans30"].mean()-3*data["cnt_loans30"].std()

data["cnt_loans30"]=np.where(data["cnt_loans30"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["cnt_loans30"]<lower_limit,
                           lower_limit,
                           data["cnt_loans30"]
                        )
                    )

# %%
sns.boxplot(data["cnt_loans30"])
# Out:
# <AxesSubplot:xlabel='cnt_loans30'>

# %%
sns.boxplot(data["amnt_loans30"])
# Out:
# <AxesSubplot:xlabel='amnt_loans30'>

# %%
upper_limit=data["amnt_loans30"].mean()+3*data["amnt_loans30"].std()
lower_limit=data["amnt_loans30"].mean()-3*data["amnt_loans30"].std()

data["amnt_loans30"]=np.where(data["amnt_loans30"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["amnt_loans30"]<lower_limit,
                           lower_limit,
                           data["amnt_loans30"]
                        )
                    )

# %%
sns.boxplot(data["amnt_loans30"])
# Out:
# <AxesSubplot:xlabel='amnt_loans30'>

# %%
sns.boxplot(data["maxamnt_loans30"])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans30'>

# %%
upper_limit=data["maxamnt_loans30"].mean()+3*data["maxamnt_loans30"].std()
lower_limit=data["maxamnt_loans30"].mean()-3*data["maxamnt_loans30"].std()

data["maxamnt_loans30"]=np.where(data["maxamnt_loans30"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["maxamnt_loans30"]<lower_limit,
                           lower_limit,
                           data["maxamnt_loans30"]
                        )
                    )

# %%
sns.boxplot(data["maxamnt_loans30"])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans30'>

# %%
sns.boxplot(data["medianamnt_loans30"])
# Out:
# <AxesSubplot:xlabel='medianamnt_loans30'>

# %%
upper_limit=data["medianamnt_loans30"].mean()+3*data["medianamnt_loans30"].std()
lower_limit=data["medianamnt_loans30"].mean()-3*data["medianamnt_loans30"].std()

data["medianamnt_loans30"]=np.where(data["medianamnt_loans30"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["medianamnt_loans30"]<lower_limit,
                           lower_limit,
                           data["medianamnt_loans30"]
                        )
                    )

# %%
sns.boxplot(data["medianamnt_loans30"])
# Out:
# <AxesSubplot:xlabel='medianamnt_loans30'>

# %%
sns.boxplot(data["cnt_loans90"])
# Out:
# <AxesSubplot:xlabel='cnt_loans90'>

# %%
upper_limit=data["cnt_loans90"].mean()+3*data["cnt_loans90"].std()
lower_limit=data["cnt_loans90"].mean()-3*data["cnt_loans90"].std()

data["cnt_loans90"]=np.where(data["cnt_loans90"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["cnt_loans90"]<lower_limit,
                           lower_limit,
                           data["cnt_loans90"]
                        )
                    )

# %%
sns.boxplot(data["cnt_loans90"])
# Out:
# <AxesSubplot:xlabel='cnt_loans90'>

# %%
sns.boxplot(data["amnt_loans90"])
# Out:
# <AxesSubplot:xlabel='amnt_loans90'>

# %%
upper_limit=data["amnt_loans90"].mean()+3*data["amnt_loans90"].std()
lower_limit=data["amnt_loans90"].mean()-3*data["amnt_loans90"].std()

data["amnt_loans90"]=np.where(data["amnt_loans90"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["amnt_loans90"]<lower_limit,
                           lower_limit,
                           data["amnt_loans90"]
                        )
                    )

# %%
sns.boxplot(data["amnt_loans90"])
# Out:
# <AxesSubplot:xlabel='amnt_loans90'>

# %%
sns.boxplot(data["maxamnt_loans90"])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans90'>

# %%
upper_limit=data["maxamnt_loans90"].mean()+3*data["maxamnt_loans90"].std()
lower_limit=data["maxamnt_loans90"].mean()-3*data["maxamnt_loans90"].std()

data["maxamnt_loans90"]=np.where(data["maxamnt_loans90"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["maxamnt_loans90"]<lower_limit,
                           lower_limit,
                           data["maxamnt_loans90"]
                        )
                    )

# %%
sns.boxplot(data["maxamnt_loans90"])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans90'>

# %%
sns.boxplot(data["medianamnt_loans90"])
# Out:
# <AxesSubplot:xlabel='medianamnt_loans90'>

# %%
upper_limit=data["medianamnt_loans90"].mean()+3*data["medianamnt_loans90"].std()
lower_limit=data["medianamnt_loans90"].mean()-3*data["medianamnt_loans90"].std()

data["medianamnt_loans90"]=np.where(data["medianamnt_loans90"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["medianamnt_loans90"]<lower_limit,
                           lower_limit,
                           data["medianamnt_loans90"]
                        )
                    )

# %%
sns.boxplot(data["medianamnt_loans90"])
# Out:
# <AxesSubplot:xlabel='medianamnt_loans90'>

# %%
sns.boxplot(data["payback30"])
# Out:
# <AxesSubplot:xlabel='payback30'>

# %%
upper_limit=data["payback30"].mean()+3*data["payback30"].std()
lower_limit=data["payback30"].mean()-3*data["payback30"].std()

data["payback30"]=np.where(data["payback30"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["payback30"]<lower_limit,
                           lower_limit,
                           data["payback30"]
                        )
                    )

# %%
sns.boxplot(data["payback30"])
# Out:
# <AxesSubplot:xlabel='payback30'>

# %%
sns.boxplot(data["payback90"])
# Out:
# <AxesSubplot:xlabel='payback90'>

# %%
upper_limit=data["payback90"].mean()+3*data["payback90"].std()
lower_limit=data["payback90"].mean()-3*data["payback90"].std()

data["payback90"]=np.where(data["payback90"]>upper_limit,
                        upper_limit,
                       np.where(
                           data["payback90"]<lower_limit,
                           lower_limit,
                           data["payback90"]
                        )
                    )

# %%
sns.boxplot(data["payback90"])
# Out:
# <AxesSubplot:xlabel='payback90'>

# %%
plt.figure(figsize=(15,20),facecolor="white")
plotnumber=1
for column in numeric_feat:
    if plotnumber <=33:
        ax=plt.subplot(11,3,plotnumber)
        sns.boxplot(data[column])
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # 8. Dropped unwanted columns from dataset

# %%
data["msisdn"].value_counts()
# Out:
# 04581I85330    7
# 47819I90840    7
# 22038I88658    6
# 94119I84456    6
# 60744I91197    6
#               ..
# 36826I90586    1
# 61456I82738    1
# 77319I90582    1
# 08674I84457    1
# 57386I88688    1
# Name: msisdn, Length: 186243, dtype: int64

# %%
data.drop("msisdn",axis=1,inplace=True)

# %%
data["pcircle"].value_counts()
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %%
data.drop("pcircle",axis=1,inplace=True)

# %%
data["pdate"].value_counts()
# Out:
# 2016-07-04    3150
# 2016-07-05    3127
# 2016-07-07    3116
# 2016-06-20    3099
# 2016-06-17    3082
#               ...
# 2016-06-04    1559
# 2016-08-18    1407
# 2016-08-19    1132
# 2016-08-20     788
# 2016-08-21     324
# Name: pdate, Length: 82, dtype: int64

# %%
data.drop("pdate",axis=1,inplace=True)

# %% [markdown]
# # Dealing with Imbalanced Target Variable

# %%
data["label"].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
s=sns.countplot(data["label"])
for p in s.patches:
    s.annotate(int(p.get_height()),(p.get_x()+0.30,p.get_height()+1),va="bottom",color="black")

# %%
total=len(data["label"])
s=sns.countplot(data["label"])
for p in s.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x()+ p.get_width()
    y = p.get_height()
    s.annotate(percentage, (x, y),ha='right')
    s.set(ylabel='label')

plt.show()

# %%
data.loc[data["label"]==0,"label"]=0
data.loc[data["label"]==1,"label"]=1

# %%
data["label"].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
class_count_1,class_count_0=data["label"].value_counts()

# %%
class_count_1
# Out:
# 183431

# %%
class_0=data[data["label"]==0]
class_1=data[data["label"]==1]

# %%
print("Class 0:",class_0.shape)
print("Class 1:",class_1.shape)
# Out:
# Class 0: (26162, 33)
# Class 1: (183431, 33)

# %%
class_0_over=class_0.sample(class_count_1,replace=True)
test_over=pd.concat([class_0_over,class_1],axis=0)
print("Total class of 1 and 0:",test_over["label"].value_counts())
# Out:
# Total class of 1 and 0: 0    183431
# 1    183431
# Name: label, dtype: int64

# %%
data=pd.DataFrame(test_over)

# %%
data["label"].value_counts()
# Out:
# 0    183431
# 1    183431
# Name: label, dtype: int64

# %%
data.shape
# Out:
# (366862, 33)

# %%
data.reset_index(drop=True,inplace=True)

# %% [markdown]
# # 9. Splitting Train and Test Data

# %%
x=data.drop("label",axis=1)

# %%
y=data.label

# %%
x.shape
# Out:
# (366862, 32)

# %%
y.shape
# Out:
# (366862,)

# %% [markdown]
# # 10. Scaling with standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_scaled=scaler.fit_transform(x)

# %% [markdown]
# # Feature Selection

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA()

# %%
principalcomponent=pca.fit_transform(x)

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("Number of Component")
plt.ylabel("Variance(%)")
plt.title("Explained variance")
plt.show()

# %%
pca=PCA(n_components=7)

# %%
pca_data=pca.fit_transform(x_scaled)

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=101)

# %%
lr=LogisticRegression()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score,classification_report,plot_confusion_matrix

# %% [markdown]
# ## Chossing Best Random State for model

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print("At random state",i,"Model perfrom well")
        print("At random state",i)
        print("Training accuracy score is-",accuracy_score(y_train,pred_train)*100)
        print("Testing accuracy score is-",accuracy_score(y_test,pred_test)*100)
# Out:
# At random state 1 Model perfrom well
# At random state 1
# Training accuracy score is- 75.89007916574182
# Testing accuracy score is- 75.88202691283766
# At random state 2 Model perfrom well
# At random state 2
# Training accuracy score is- 75.88774274443834
# Testing accuracy score is- 75.86839785932999
# At random state 4 Model perfrom well
# At random state 4
# Training accuracy score is- 75.90409769356276
# Testing accuracy score is- 75.91019362342017
# At random state 5 Model perfrom well
# At random state 5
# Training accuracy score is- 75.91188576457441
# Testing accuracy score is- 75.92291407336064
# At random state 6 Model perfrom well
# At random state 6
# Training accuracy score is- 75.93602878471046
# Testing accuracy score is- 75.85295159868798
# At random state 9 Model perfrom well
# At random state 9
# Training accuracy score is- 75.91305397522615
# Testing accuracy score is- 75.91655384839041
# At random state 15 Model perfrom well
# At random state 15
# ...

# %% [markdown]
# **We can choose best Random state 74**

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=74)

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Evaluation Matrix

# %%
y_pred=lr.predict(x_test)

# %%
lr_acc_score=accuracy_score(y_test,y_pred)

# %%
lr_acc_score
# Out:
# 0.7617096284720014

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[44932, 10399],
#        [15827, 38901]], dtype=int64)

# %%
print("Logistic Regression")
plot_confusion_matrix(lr,x_test,y_test,values_format=".6g");
# Out:
# Logistic Regression

# %%
confusion_matrix(y_test,y_pred)
pd.crosstab(y_test, y_pred, rownames = ['Actual'], colnames =['Predicted'], margins = True)
# Out:
# Predicted      0      1     All
# Actual
# 0          45680   9651   55331
# 1          13446  41282   54728
# All        59126  50933  110059

# %%
print("Logistic Regression")
print(classification_report(y_test,y_pred,digits=2))
# Out:
# Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77     55331
#            1       0.79      0.71      0.75     54728
#
#     accuracy                           0.76    110059
#    macro avg       0.76      0.76      0.76    110059
# weighted avg       0.76      0.76      0.76    110059

# %% [markdown]
# ## 17.4 Finding Best CV for model

# %%
from sklearn.model_selection import cross_val_score,cross_validate

# %%
for j in range(2,6):
    lr_score=cross_val_score(lr,x_scaled,y,cv=j)
    lr_s=lr_score.mean()
    print("At CV:-",j)
    print("Cross validation score is:",lr_score*100)
    print("Accuracy Score:",lr_s*100)
    print('\n')
# Out:
# At CV:- 2
# Cross validation score is: [75.81979055 75.93645567]
# Accuracy Score: 75.87812310896196
#
#
# At CV:- 3
# Cross validation score is: [75.80465786 75.88705259 75.99090664]
# Accuracy Score: 75.89420569464224
#
#
# At CV:- 4
# Cross validation score is: [75.7773998  75.88861267 75.97448618 75.97339585]
# Accuracy Score: 75.90347362478201
#
#
# At CV:- 5
# Cross validation score is: [75.6967822  76.0170635  75.745516   76.10532628 75.89407403]
# Accuracy Score: 75.89175240188167

# %% [markdown]
# **We can choose best CV 4**

# %%
cross_val_score(lr,x_scaled,y,cv=4)
# Out:
# array([0.7581338 , 0.76020542, 0.75929782, 0.76012648])

# %%
lr_cv_score=cross_val_score(lr,x_scaled,y,cv=4).mean()

# %%
lr_cv_score
# Out:
# 0.7594408811556969

# %%
lr_acc_score
# Out:
# 0.7617096284720014

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.30, random_state=74)

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ## Evaluation Matrix

# %%
y_pred=rfc.predict(x_test)

# %%
rfc_acc_score=accuracy_score(y_test,y_pred)

# %%
rfc_acc_score
# Out:
# 0.9747499068681343

# %%
confusion_matrix(y_test,y_pred)
pd.crosstab(y_test, y_pred, rownames = ['Actual'], colnames =['Predicted'], margins = True)
# Out:
# array([[55138,   193],
#        [ 2586, 52142]], dtype=int64)

# %%
print("Random Forest Classifier")
plot_confusion_matrix(rfc,x_test,y_test,values_format=".6g");
# Out:
# Random Forest Classifier

# %%
print("Random Forest Classifier")
print(classification_report(y_test,y_pred,digits=2))
# Out:
# Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     55331
#            1       1.00      0.95      0.97     54728
#
#     accuracy                           0.97    110059
#    macro avg       0.98      0.97      0.97    110059
# weighted avg       0.98      0.97      0.97    110059

# %% [markdown]
# ## Choosing Best CV for Model

# %%
for j in range(2,6):
    rfc_score=cross_val_score(rfc,x_scaled,y,cv=j)
    rfc_s=rfc_score.mean()
    print("At CV:-",j)
    print("Cross validation score is:",rfc_score*100)
    print("Accuracy Score:",rfc_s*100)
    print('\n')
# Out:
# At CV:- 2
# Cross validation score is: [96.26180962 96.29070332]
# Accuracy Score: 96.27625646700939
#
#
# At CV:- 3
# Cross validation score is: [97.30145231 97.34313541 97.38811157]
# Accuracy Score: 97.34423309795179
#
#
# At CV:- 4
# Cross validation score is: [97.65580706 97.67434254 97.66777517 97.73755656]
# Accuracy Score: 97.683870331599
#
#
# At CV:- 5
# Cross validation score is: [97.85888542 97.82753874 97.8097912  97.82750913 97.88202584]
# Accuracy Score: 97.84115006698968

# %% [markdown]
# **We can choose Best CV 5**

# %%
cross_val_score(rfc,x_scaled,y,cv=5)
# Out:
# array([0.97805732, 0.97853434, 0.97774355, 0.97787985, 0.97826146])

# %%
rfc_cv_score=cross_val_score(rfc,x_scaled,y,cv=5).mean()

# %%
rfc_acc_score
# Out:
# 0.9747499068681343

# %%
rfc_cv_score
# Out:
# 0.9785096300780584

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.30, random_state=74)

# %%
svc=SVC()

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %% [markdown]
# ## Evaluation Matrix

# %%
y_pred=svc.predict(x_test)

# %%
svc_acc_score=accuracy_score(y_test,y_pred)

# %%
svc_acc_score
# Out:
# 0.7901398340889886

# %%
confusion_matrix(y_test,y_pred)
pd.crosstab(y_test, y_pred, rownames = ['Actual'], colnames =['Predicted'], margins = True)
# Out:
# Predicted      0      1     All
# Actual
# 0          45680   9651   55331
# 1          13446  41282   54728
# All        59126  50933  110059

# %%
print("Support Vector Classifier")
plot_confusion_matrix(svc,x_test,y_test,values_format=".4g");
# Out:
# Support Vector Classifier

# %%
print("Support Vector Classifier")
print(classification_report(y_test,y_pred,digits=2))
# Out:
# Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80     55331
#            1       0.81      0.75      0.78     54728
#
#     accuracy                           0.79    110059
#    macro avg       0.79      0.79      0.79    110059
# weighted avg       0.79      0.79      0.79    110059

# %%
cross_val_score(svc,x_scaled,y,cv=2)
# Out:
# array([0.78686809, 0.7890651 ])

# %%
svc_cv_score=cross_val_score(svc,x_scaled,y,cv=2).mean()

# %%
svc_acc_score
# Out:
# 0.7901398340889886

# %%
svc_cv_score
# Out:
# 0.7879665923426247

# %% [markdown]
# # Lets choose the best model with ROC AUC Curve

# %%
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.metrics import plot_roc_curve

# %%
lr_pred=lr.predict(x_test)
rfc_pred=rfc.predict(x_test)
svc_pred=svc.predict(x_test)

# %%
# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, lr_pred, pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, rfc_pred, pos_label=1)
fpr3, tpr3, thresh3 = roc_curve(y_test, svc_pred, pos_label=1)

# %%
# roc curve for tpr = fpr 
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

# %%
# auc scores
auc_score_lr = roc_auc_score(y_test, lr_pred)
auc_score_rfc = roc_auc_score(y_test, rfc_pred)
auc_score_svc = roc_auc_score(y_test, svc_pred)

print(round(auc_score_lr,2)*100, round(auc_score_rfc,2)*100,round(auc_score_svc,2)*100)
# Out:
# 76.0 97.0 79.0

# %%
plt.figure(figsize=(10,8))
plt.plot(fpr1, tpr1, linestyle='--',color='darkorange',linewidth=4, label='Logistic Regression(area=%0.2f)'% auc_score_lr)
plt.plot(fpr2, tpr2, linestyle='--',color='green',linewidth=4, label='Random Forest Classifier (area=%0.2f)'% auc_score_rfc)
plt.plot(fpr3,tpr3,linestyle='--',color='navy',linewidth=4, label='Support Vector Machine Classifier(area=%0.2f)'% auc_score_svc)



plt.plot(p_fpr, p_tpr, linestyle='--', color='red')
# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(prop={'size':11},loc='lower right')
plt.savefig('ROC',dpi=300)
plt.show();

# %% [markdown]
# **As we can see from above plot Random Forest Classifier working better**`

# %% [markdown]
# # Choosing best model by checking cross validation score

# %%
Logistic_Regression={"Accuracy Score":(lr_acc_score,2),
                    "CV Score":(lr_cv_score,2),
                    "Difference":lr_acc_score-lr_cv_score}
Random_Forest_Classifier={"Accuracy Score":(rfc_acc_score,2),
                    "CV Score":(rfc_cv_score,2),
                    "Difference":rfc_acc_score-rfc_cv_score}
Support_Vector_Machine_Classifier={"Accuracy Score":(svc_acc_score,2),
                    "CV Score":(svc_cv_score,2),
                    "Difference":svc_acc_score-svc_cv_score}

# %%
data=np.array([[lr_acc_score,lr_cv_score,lr_acc_score-lr_cv_score],[rfc_acc_score,rfc_cv_score,rfc_acc_score-rfc_cv_score],[svc_acc_score,svc_cv_score,svc_acc_score-svc_cv_score]])

# %%
index_value=["LogisticRegression","RandomForestClassifier","SupportVectorMachineClassifier"]

# %%
columns_value=["Accuracy Score","Cross Validation Score","Difference"]

# %%
model_selection=pd.DataFrame(data=data,
                            index=index_value,
                            columns=columns_value)

# %%
model_selection
# Out:
#                                 Accuracy Score  Cross Validation Score  \
# LogisticRegression                     0.76171                0.759441
# RandomForestClassifier                 0.97475                0.978510
# SupportVectorMachineClassifier         0.79014                0.787967
#
#                                 Difference
# LogisticRegression                0.002269
# RandomForestClassifier           -0.003760
# SupportVectorMachineClassifier    0.002173

# %% [markdown]
# **We will choose Random forest Classifier as best model**

# %% [markdown]
# # Saving the Model

# %%
import pickle
filename="micro_credit.pkl"
pickle.dump(rfc,open(filename,"wb"))
